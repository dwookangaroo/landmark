# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm



import numpy as np
import os
import shutil

import tensorflow as tf

from tensorflow import keras

# from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras import optimizers, initializers, regularizers, metrics
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras import layers

from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12041356986106362794
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4986830848
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10111776485850669474
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]

# %%
from io import BytesIO
import time, random
from tqdm import tqdm

from PIL import Image

# %%
BASE_DIR = "D:/original_image/"
names =  ["63building", "castle","coex","general", "indep_door","judgement_castle","lotte_tower","moonlight",\
                "namsan", "seoulstation","tapgol_park"]

tf.random.set_seed(1)

# %%
if not os.path.isdir(BASE_DIR + 'train/'):
    for name in names:
        os.makedirs(BASE_DIR + 'train/' + name)
        os.makedirs(BASE_DIR + 'val/' + name)
        os.makedirs(BASE_DIR + 'test/' + name)

# %%
org_folders =  ["63building/", "castle/","coex/","general/", "indep_door/","judgement_castle/","lotte_tower/","moonlight/",\
                "namsan/", "seoulstation/","tapgol_park/"]

# %%
# for folder_idx, folder in enumerate(orig_folders):
#     files = os.listdir(BASE_DIR + folder)
#     number_of_images = len([name for name in files])
#     n_train = int((number_of_images * 0.6) + 0.5)
#     n_valid = int((number_of_images* 0.25) + 0.5)
#     n_test = number_of_images - n_train - n_valid
#     print(number_of_images, n_train, n_valid, n_test)
#     for idx, file in enumerate(files):
#         file_name = BASE_DIR + folder + file
#         if idx < n_train:
#             shutil.move(file_name, BASE_DIR + "train/" + names[folder_idx])
#         elif idx < n_train + n_valid:
#             shutil.move(file_name, BASE_DIR + "val/" + names[folder_idx])
#         else:
#             shutil.move(file_name, BASE_DIR + "test/" + names[folder_idx])

# %%
for folder_idx, folder in enumerate(org_folders):
    sample_list = [x for x in os.listdir(BASE_DIR + folder)]
    
    not_train_list = random.sample(sample_list, int(len(sample_list)*0.4))
    train_list = [x for x in sample_list if x not in not_train_list]
    validation_list = random.sample(not_train_list, int(len(not_train_list)/2))
    test_list = [x for x in not_train_list if x not in validation_list]
    

    for file in tqdm(test_list):
        image = Image.open(BASE_DIR + folder + file)
        image.save(BASE_DIR + "test/"+ folder + file)

    for file in tqdm(validation_list):
        image = Image.open(BASE_DIR + folder + file)
        image.save(BASE_DIR + "val/"+ folder + file)

    for file in tqdm(train_list):
        image = Image.open(BASE_DIR + folder + file)
        image.save(BASE_DIR + "train/"+ folder + file)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:01<00:00, 108.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 236.96it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:02<00:00, 254.68it/s]
#   0%|▍                                                                                 | 1/200 [00:00<00:09, 20.85it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18084/619577878.py in <module>
#       9
#      10     for file in tqdm(test_list):
# ---> 11         image = Image.open(BASE_DIR + folder + file)
#      12         image.save(BASE_DIR + "test/"+ folder + file)
#      13
#
# ~\anaconda3\envs\project-env\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2966
#    2967     if filename:
# -> 2968         fp = builtins.open(filename, "rb")
#    2969         exclusive_fp = True
#    2970
#
# KeyboardInterrupt:

# %%
train_gen = keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
valid_gen = keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_gen = keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
# final_test_gen = keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

#train에 저장
train_batches = train_gen.flow_from_directory(
    'D:/original_image/train',
    target_size = (240, 240),
    class_mode = 'sparse',
    batch_size = 2,
    shuffle=True,
    color_mode="rgb",
    classes=names
)

#val에 저장
val_batches = valid_gen.flow_from_directory(
    'D:/original_image/val',
    target_size = (240, 240),
    class_mode = 'sparse',
    batch_size = 2,
    shuffle=False,
    color_mode="rgb",
    classes=names
)

#테스트에 저장
test_batches = test_gen.flow_from_directory(
    'D:/original_image/test',
    target_size = (240, 240),
    class_mode = 'sparse',
    batch_size = 2,
    shuffle=False,
    color_mode="rgb",
    classes=names
)

# 최종 테스트
# final_test_batches = final_test_gen.flow_from_directory(
#     'D:/sub_final_test/',
#     target_size = (240, 240),
#     class_mode = 'sparse',
#     batch_size = 2,
#     shuffle=False,
#     color_mode="rgb"
# )
# Out:
# Found 6600 images belonging to 11 classes.
# Found 2200 images belonging to 11 classes.
# Found 2200 images belonging to 11 classes.

# %%
model = keras.models.Sequential()
model.add(layers.Conv2D(32, (3,3), strides=(1,1), padding="valid", activation='relu', input_shape=(240,240,3)))
model.add(layers.MaxPool2D(2,2))

# %%
train_batch = train_batches[0]
print(train_batch[0].shape)
print(train_batch[1])

test_batch = test_batches[0]
print(test_batch[0].shape)
print(test_batch[1])
# Out:
# (2, 240, 240, 3)
# [1. 3.]
# (2, 240, 240, 3)
# [0. 0.]

# %%
# vgg 모델
vgg_model = tf.keras.applications.vgg16.VGG16()
print(type(vgg_model))
vgg_model.summary()
# Out:
# <class 'tensorflow.python.keras.engine.training.Model'>
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = tf.keras.models.Sequential()
for layer in vgg_model.layers[0:-1]:
    model.add(layer)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 마지막 레이어만 train해주면됨
#앞에 레이어 non trainable로 바꿔줌
for layer in model.layers:
    layer.trainable = False
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 0
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %%
model.add(layers.Dense(11))

# %%
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optim = keras.optimizers.Adam(lr=0.001)
metrics = ["accuracy"]

model.compile(optimizer=optim, loss=loss, metrics=metrics)

# %%
preprocess_input = tf.keras.applications.vgg16.preprocess_input

# %%
train_gen = keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)
valid_gen = keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)
test_gen = keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)
# final_test_gen = keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocess_input)

train_batches = train_gen.flow_from_directory(
    'D:/original_image/train',
    target_size = (240, 240),
    class_mode = 'sparse',
    batch_size = 2,
    shuffle=True,
    color_mode="rgb",
    classes=names
)

val_batches = valid_gen.flow_from_directory(
    'D:/original_image/val',
    target_size = (240, 240),
    class_mode = 'sparse',
    batch_size = 2,
    shuffle=False,
    color_mode="rgb",
    classes=names
)

test_batches = test_gen.flow_from_directory(
    'D:/original_image/test',
    target_size = (240, 240),
    class_mode = 'sparse',
    batch_size = 2,
    shuffle=False,
    color_mode="rgb",
    classes=names
)

# final_test_batches = final_test_gen.flow_from_directory(
#     'D:/sub_final_test/',
#     target_size = (240, 240),
#     class_mode = 'sparse',
#     batch_size = 2,
#     shuffle=False,
#     color_mode="rgb"
# )
# Out:
# Found 6600 images belonging to 11 classes.
# Found 2200 images belonging to 11 classes.
# Found 2200 images belonging to 11 classes.

# %%
epochs = 15

early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5
)

history = model.fit(train_batches, validation_data=val_batches,
         callbacks=[early_stopping],
         epochs=epochs)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 3300 steps, validate for 1100 steps
# Epoch 1/15
# 3300/3300 [==============================] - 91s 28ms/step - loss: 0.0586 - accuracy: 0.9865 - val_loss: 0.0051 - val_accuracy: 0.9991
# Epoch 2/15
# 3300/3300 [==============================] - 89s 27ms/step - loss: 0.0144 - accuracy: 0.9968 - val_loss: 0.0077 - val_accuracy: 0.9982
# Epoch 3/15
# 3300/3300 [==============================] - 90s 27ms/step - loss: 0.0183 - accuracy: 0.9977 - val_loss: 0.0163 - val_accuracy: 0.9982
# Epoch 4/15
# 3300/3300 [==============================] - 90s 27ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0086 - val_accuracy: 0.9995
# Epoch 5/15
# 3300/3300 [==============================] - 91s 28ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.0253 - val_accuracy: 0.9968
# Epoch 6/15
# 3300/3300 [==============================] - 91s 28ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 4.7587e-07 - val_accuracy: 1.0000
# Epoch 7/15
# 3300/3300 [==============================] - 92s 28ms/step - loss: 3.7441e-06 - accuracy: 1.0000 - val_loss: 4.5770e-07 - val_accuracy: 1.0000
# Epoch 8/15
# 3300/3300 [==============================] - 91s 28ms/step - loss: 3.2980e-08 - accuracy: 1.0000 - val_loss: 6.4328e-07 - val_accuracy: 1.0000
# Epoch 9/15
# 3300/3300 [==============================] - 91s 28ms/step - loss: 1.0458e-08 - accuracy: 1.0000 - val_loss: 6.6381e-07 - val_accuracy: 1.0000
# Epoch 10/15
# 3300/3300 [==============================] - 92s 28ms/step - loss: 3.9736e-09 - accuracy: 1.0000 - val_loss: 3.1336e-07 - val_accuracy: 1.0000
# Epoch 11/15
# 3300/3300 [==============================] - 91s 28ms/step - loss: 1.2102e-09 - accuracy: 1.0000 - val_loss: 4.7200e-07 - val_accuracy: 1.0000
# Epoch 12/15
# 3300/3300 [==============================] - 92s 28ms/step - loss: 5.2380e-10 - accuracy: 1.0000 - val_loss: 3.7938e-07 - val_accuracy: 1.0000
# Epoch 13/15
# 3300/3300 [==============================] - 91s 27ms/step - loss: 1.0837e-10 - accuracy: 1.0000 - val_loss: 4.1555e-07 - val_accuracy: 1.0000
# Epoch 14/15
# 3300/3300 [==============================] - 91s 27ms/step - loss: 5.4186e-11 - accuracy: 1.0000 - val_loss: 4.4852e-07 - val_accuracy: 1.0000
# Epoch 15/15
# 3300/3300 [==============================] - 91s 27ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 8.2208e-07 - val_accuracy: 1.0000

# %%
loss, acc = model.evaluate(test_batches)
acc
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 1100/1100 [==============================] - 22s 20ms/step - loss: 6.4423e-08 - accuracy: 1.00000s - loss: 6.4954e-08 - accuracy:
# 1.0

# %%
model.save('model/trained_model.h5')

# %%
new_model = load_model('model/trained_model.h5')

# %%
# new_model.evaluate(final_test_batches)
# Out:
# 1088/1088 [==============================] - 89s 81ms/step - loss: 0.2284 - accuracy: 0.9743
# [0.22842630091589292, 0.9742529]

# %%
# datagen = ImageDataGenerator(
#         rotation_range=2,
#         width_shift_range=0.05,
#         height_shift_range=0.05,
#         shear_range=0.05,
#         zoom_range = 0.1,
#         horizontal_flip=False,
#         fill_mode="nearest")

# folder = "D:/sub_final_test"

# file_list = [x for x in os.listdir(folder)]

# # sub_folder = "D:/final_test/" + "63buliding"
# # sub_file_list = [x for x in os.listdir(sub_folder)]

# for i in tqdm(range(len(file_list))):
#     sub_folder = "D:/sub_final_test/" + file_list[i]
#     sub_file_list = [x for x in os.listdir(sub_folder)]

#     for j in range(len(sub_file_list)):
#         image = load_img("D:/sub_final_test/" + file_list[i] +"/" + sub_file_list[j])  # PIL 이미지
#         x = img_to_array(image)  # (3, 300, 300) 크기의 NumPy 배열
#         x = x.reshape((1,) + x.shape)  # (1, 3, 300, 300) 크기의 NumPy 배열

#     #     아래 .flow() 함수는 임의 변환된 이미지를 배치 단위로 생성해서
#     #     지정된 `preview/` 폴더에 저장합니다.
#         k = 0
#         for batch in datagen.flow(x, batch_size=5,
#                                   save_to_dir="D:/sub_final_test/" + file_list[i], save_prefix="super_" + file_list[i], save_format="jpg"):
#             k += 1
#             time.sleep(0.01)
#             if k > 18:
#                 break  # 이미지 50장을 생성하고 마칩니다

# %%
# prediction = new_model.predict(final_test_batches)

# %%
import glob

# %%
caltech_dir = "D:/final_test"


X = []
filenames = []
files = glob.glob(caltech_dir+"/*.*")
for i, f in enumerate(files):
    img = Image.open(f)
    img = img.resize((224,224))
    img = img.convert("RGB")
    data = np.asarray(img)
    filenames.append(f)
    X.append(data)

X = np.array(X)

# %%
X[0]
# Out:
# array([[[ 90, 122, 163],
#         [ 93, 125, 166],
#         [ 97, 129, 170],
#         ...,
#         [186, 196, 216],
#         [180, 194, 217],
#         [179, 195, 220]],
#
#        [[ 90, 122, 163],
#         [ 94, 123, 165],
#         [ 98, 127, 171],
#         ...,
#         [186, 196, 214],
#         [180, 195, 214],
#         [180, 197, 217]],
#
#        [[ 92, 121, 165],
#         [ 94, 123, 167],
#         [ 96, 125, 169],
#         ...,
#         [186, 199, 216],
#         [185, 200, 216],
#         [185, 200, 216]],
#
#        ...,
#
#        [[153, 161, 172],
#         [153, 161, 172],
#         [153, 161, 172],
#         ...,
#         [ 19,  26,  34],
#         [ 20,  24,  33],
#         [ 20,  24,  33]],
#
#        [[150, 156, 168],
#         [151, 157, 169],
#         [152, 158, 170],
#         ...,
#         [ 21,  28,  36],
#         [ 20,  27,  35],
#         [ 20,  27,  35]],
#
#        [[152, 156, 167],
#         [153, 157, 168],
#         [154, 158, 169],
#         ...,
#         [ 20,  29,  36],
#         [ 19,  28,  35],
#         [ 19,  28,  35]]], dtype=uint8)

# %%
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
cnt = 0

# %%
new_prediction = new_model.predict(X)

# %%
final_names = ["63building", "castle","coex","general", "indep_door","judgement_castle","lotte_tower","moonlight",\
                "namsan", "seoulstation","tapgol_park"]

cnt=0
right_answer=0
error=0

# 이 비교는 그냥 파일들이 있으면 해당 파일과 비교. 카테고리와 함께 비교해서 진행하는 것은 _4 파일.
for i in new_prediction:
    pre_ans = i.argmax()  # 예측 레이블
    pre_ans_str = ''
    
    if pre_ans == 0: pre_ans_str = "63buliding"
    elif pre_ans == 1: pre_ans_str = "castle"
    elif pre_ans == 2: pre_ans_str = "coex"
    elif pre_ans == 3: pre_ans_str = "general"
    elif pre_ans == 4: pre_ans_str = "indep_door"
    elif pre_ans == 5: pre_ans_str = "judgement_castle"
    elif pre_ans == 6: pre_ans_str = "lotte_tower"
    elif pre_ans == 7: pre_ans_str = "moonlight"
    elif pre_ans == 8: pre_ans_str = "namsan"
    elif pre_ans == 9: pre_ans_str = "seoulstation"
    elif pre_ans == 10: pre_ans_str = "tapgol_park"
        
        
    else: pre_ans_str = "what the!!"
        

#     if i[0] >= 0.8 : print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
#     if i[1] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"으로 추정됩니다.")
#     if i[2] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
#     if i[3] >= 0.8 : print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
#     if i[4] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"으로 추정됩니다.")
#     if i[5] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
#     if i[6] >= 0.8 : print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
#     if i[7] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"으로 추정됩니다.")
#     if i[8] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
#     if i[9] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"으로 추정됩니다.")
#     if i[10] >= 0.8: print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")

    print("해당 "+filenames[cnt].split("\\")[1]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    cnt += 1
    
    try:        
        if pre_ans_str in filenames[cnt].split("\\")[1]:
            right_answer+=1
        else:
            error+=1
    except:
        pass

    #얘가 레이블 [1. 0. 0.] 이런식으로 되어 있는 것을 숫자로 바꿔주는 것.
#     즉 얘랑, 나중에 카테고리 데이터 불러와서 카테고리랑 비교를 해서 같으면 맞는거고, 아니면 틀린거로 취급하면 된다.
#     이걸 한 것은 _4.py에.

percent=round((right_answer/(right_answer + error)),4)
print(percent)
print(right_answer+error)
print(len(new_prediction))
# Out:
# 해당 63buliding1.jpg이미지는 63buliding로 추정됩니다.
# 해당 63buliding10.jpg이미지는 63buliding로 추정됩니다.
# 해당 63buliding2.jpg이미지는 63buliding로 추정됩니다.
# 해당 63buliding3.jpg이미지는 63buliding로 추정됩니다.
# 해당 63buliding4.jpg이미지는 63buliding로 추정됩니다.
# 해당 63buliding5.jpg이미지는 63buliding로 추정됩니다.
# 해당 63buliding6.jpg이미지는 general로 추정됩니다.
# 해당 63buliding7.jpg이미지는 63buliding로 추정됩니다.
# 해당 63buliding8.jpg이미지는 63buliding로 추정됩니다.
# 해당 63buliding9.jpg이미지는 63buliding로 추정됩니다.
# 해당 castle1.jpg이미지는 castle로 추정됩니다.
# 해당 castle10.jpg이미지는 castle로 추정됩니다.
# 해당 castle2.jpg이미지는 castle로 추정됩니다.
# 해당 castle3jpg.jpg이미지는 castle로 추정됩니다.
# 해당 castle4.jpg이미지는 castle로 추정됩니다.
# 해당 castle5.jpg이미지는 castle로 추정됩니다.
# 해당 castle6.jpg이미지는 castle로 추정됩니다.
# 해당 castle7.jpg이미지는 castle로 추정됩니다.
# 해당 castle8.jpg이미지는 castle로 추정됩니다.
# 해당 castle9.jpg이미지는 castle로 추정됩니다.
# 해당 coex1.jpg이미지는 coex로 추정됩니다.
# 해당 coex10.jpg이미지는 coex로 추정됩니다.
# 해당 coex2.jpg이미지는 coex로 추정됩니다.
# 해당 coex3.jpg이미지는 coex로 추정됩니다.
# 해당 coex4.jpg이미지는 general로 추정됩니다.
# 해당 coex5.jpg이미지는 coex로 추정됩니다.
# 해당 coex6.jpg이미지는 coex로 추정됩니다.
# 해당 coex7.jpg이미지는 coex로 추정됩니다.
# 해당 coex8.jpg이미지는 general로 추정됩니다.
# 해당 coex9.jpg이미지는 coex로 추정됩니다.
# 해당 general1.jpg이미지는 general로 추정됩니다.
# 해당 general10.jpg이미지는 general로 추정됩니다.
# 해당 general2.jpg이미지는 general로 추정됩니다.
# 해당 general3.jpg이미지는 general로 추정됩니다.
# 해당 general4.jpg이미지는 general로 추정됩니다.
# 해당 general5.jpg이미지는 general로 추정됩니다.
# 해당 general6.jpg이미지는 tapgol_park로 추정됩니다.
# 해당 general7.jpg이미지는 general로 추정됩니다.
# 해당 general8.jpg이미지는 namsan로 추정됩니다.
# 해당 general9.jpg이미지는 general로 추정됩니다.
# 해당 indep_door1.jpg이미지는 indep_door로 추정됩니다.
# 해당 indep_door10.jpg이미지는 indep_door로 추정됩니다.
# 해당 indep_door2.jpg이미지는 indep_door로 추정됩니다.
# 해당 indep_door3.jpg이미지는 indep_door로 추정됩니다.
# 해당 indep_door4.jpg이미지는 indep_door로 추정됩니다.
# 해당 indep_door5.jpg이미지는 indep_door로 추정됩니다.
# 해당 indep_door6.jpg이미지는 indep_door로 추정됩니다.
# 해당 indep_door7.jpg이미지는 indep_door로 추정됩니다.
# 해당 indep_door8.jpg이미지는 indep_door로 추정됩니다.
# 해당 indep_door9.jpg이미지는 indep_door로 추정됩니다.
# 해당 judgement_castle1.jpg이미지는 judgement_castle로 추정됩니다.
# 해당 judgement_castle10.jpg이미지는 judgement_castle로 추정됩니다.
# 해당 judgement_castle2.jpg이미지는 judgement_castle로 추정됩니다.
# 해당 judgement_castle3.jpg이미지는 judgement_castle로 추정됩니다.
# 해당 judgement_castle4.jpg이미지는 judgement_castle로 추정됩니다.
# 해당 judgement_castle5.jpg이미지는 judgement_castle로 추정됩니다.
# 해당 judgement_castle6.jpg이미지는 tapgol_park로 추정됩니다.
# 해당 judgement_castle7.jpg이미지는 general로 추정됩니다.
# 해당 judgement_castle8.jpg이미지는 castle로 추정됩니다.
# 해당 judgement_castle9.jpg이미지는 indep_door로 추정됩니다.
# 해당 lotte_tower1.jpg이미지는 lotte_tower로 추정됩니다.
# 해당 lotte_tower10.jpg이미지는 lotte_tower로 추정됩니다.
# 해당 lotte_tower2.jpg이미지는 lotte_tower로 추정됩니다.
# 해당 lotte_tower3.jpg이미지는 lotte_tower로 추정됩니다.
# 해당 lotte_tower4.jpg이미지는 lotte_tower로 추정됩니다.
# 해당 lotte_tower5.jpg이미지는 lotte_tower로 추정됩니다.
# 해당 lotte_tower6.jpg이미지는 lotte_tower로 추정됩니다.
# 해당 lotte_tower7.jpg이미지는 lotte_tower로 추정됩니다.
# 해당 lotte_tower8.jpg이미지는 lotte_tower로 추정됩니다.
# 해당 lotte_tower9.jpg이미지는 lotte_tower로 추정됩니다.
# 해당 moonlight1.jpg이미지는 moonlight로 추정됩니다.
# 해당 moonlight10.jpg이미지는 moonlight로 추정됩니다.
# 해당 moonlight2.jpg이미지는 moonlight로 추정됩니다.
# 해당 moonlight3.jpg이미지는 moonlight로 추정됩니다.
# 해당 moonlight4.jpg이미지는 moonlight로 추정됩니다.
# 해당 moonlight5.jpg이미지는 moonlight로 추정됩니다.
# 해당 moonlight6.jpg이미지는 moonlight로 추정됩니다.
# 해당 moonlight7.jpg이미지는 moonlight로 추정됩니다.
# 해당 moonlight8.jpg이미지는 moonlight로 추정됩니다.
# 해당 moonlight9.jpg이미지는 moonlight로 추정됩니다.
# 해당 namsan1.jpg이미지는 namsan로 추정됩니다.
# 해당 namsan10.jpg이미지는 namsan로 추정됩니다.
# 해당 namsan2.jpg이미지는 namsan로 추정됩니다.
# 해당 namsan3.jpg이미지는 namsan로 추정됩니다.
# 해당 namsan4.jpg이미지는 namsan로 추정됩니다.
# 해당 namsan5.jpg이미지는 namsan로 추정됩니다.
# 해당 namsan6.jpg이미지는 namsan로 추정됩니다.
# 해당 namsan7.jpg이미지는 namsan로 추정됩니다.
# 해당 nams